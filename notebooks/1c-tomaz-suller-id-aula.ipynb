# %%
import re
from datetime import date
from urllib.parse import urljoin

import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

from polimi_scraper.config import logger, DataPath
from polimi_scraper.utils import occupancy_soup

# %%
URL = "https://www7.ceda.polimi.it/spazi/spazi/controller/OccupazioniGiornoEsatto.do"

# %%
sede_df = pd.read_parquet("sede.parquet")
sede_df
# Out:
#    codice_patrimonio tipo_patrimonio                           infoWindow  \
# 0                COE           GSede                <strong>Como</strong>
# 1                CRG           GSede             <strong>Cremona</strong>
# 2                LCF           GSede               <strong>Lecco</strong>
# 3                MIB           GSede       <strong>Milano Bovisa</strong>
# 4                PCL           GSede            <strong>Piacenza</strong>
# 5                MIA           GSede  <strong>Milano Città Studi</strong>
# 6                MNI           GSede             <strong>Mantova</strong>
# 7                MID           GSede     <strong>Sesto Ulteriano</strong>
# 8                MIC           GSede             <strong>Servizi</strong>
# 9                MIF           GSede      <strong>Milano Tortona</strong>
# 10               GEM           GSede              <strong>Genova</strong>
#
#    radius  center.lat  center.lng
# 0     500   45.805110    9.092083
# 1     500   45.146390   10.001993
# 2     500   45.849515    9.396736
# 3     500   45.503867    9.160379
# 4     500   45.046598    9.702332
# 5     500   45.481120    9.232041
# 6     500   45.160258   10.788716
# 7     500   45.393487    9.257306
# 8     500   45.461827    9.180636
# 9     500   45.450113    9.158053
# 10    500   44.423819    8.733635

# %% [markdown]
# ## Experiment

# %%
parameters = {
    "csic": "MIB",
    "categoria": "tutte",
    "tipologia": "tutte",
    "giorno_day": 1,
    "giorno_month": 2,
    "giorno_year": 2025,
    "evn_visualizza": "",
}

# %%
soup = BeautifulSoup(requests.get(URL, params=parameters).text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <title>Occupazioni per Data</title>
# <link href="https://webcommons.polimi.it/webcommons/assets/ateneo2014.css.jsp?v=5&amp;lang=it&amp;dt_version=1.10" rel="stylesheet" type="text/css"/>
# <link href="https://webcommons.polimi.it/webcommons/ajax/libs/jqueryui/1.12.1/themes/polij.css.jsp?v=5&amp;lang=it" rel="stylesheet" type="text/css"/>
# <link href="https://webcommons.polimi.it/webcommons/assets/desktop.css.jsp?v=5&amp;lang=it" rel="stylesheet" type="text/css"/>
# <link href="/spazi/assets/css/base.css?__load_ts=1737140432539" rel="stylesheet" type="text/css"/>
# <script src="https://webcommons.polimi.it/webcommons/ajax/libs/jqueryui/1.12.1/ui.js.jsp?v=5&amp;lang=it&amp;dt_version=1.10" type="text/javascript"></script>
# <script src="https://webcommons.polimi.it/webcommons/ajax/libs/desktop.js.jsp?v=5&amp;lang=it" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('#loading').remove();
# 	});
# </script>
# </head>
# <body>
# <div id="jafBodyContainer">
# <div id="polijPageHeader">
# <table id="poliheader">
# <tr>
# <td class="jaf-text-align-left td-logo-polimi">
# <a href="http://www.polimi.it" title="polimi.it">
# <img alt="logo-polimi" class="logo-polimi" src="https://webcommons.polimi.it/webcommons/assets/logo_polimi_testo.png"/>
# </a>
# <div id="loading">
# <strong>La pagina è in caricamento...</strong><div class="jaf-loading-bar thin" style="max-width: 200px;"></div>
# </div>
# </td>
# <td class="jaf-text-align-center info-DB">
# </td>
# <td class="jaf-text-align-right info-utente">
# </td>
# </tr>
# </table>
# <div id="policontext">
# <nav class="nomeApp policontext-link" style="float: left; margin: auto 1em;">
# 		 spazi
# 	</nav>
# <div class="policontext-link">
# <nav>
# <a href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_jaf_cambio_lingua=event&amp;lang=EN&amp;screenName=/pagine/occupazioni/occupazioniGiornoEsatto.jsp&amp;freezecount=true&amp;jaf_currentWFID=main&amp;polij_step=0&amp;__pj0=0&amp;__pj1=e668d449068b0d05e19d5697348b671b" title="English"><img alt="English" src="//webcommons.polimi.it/webcommons/assets/english.gif" title="English"/></a>
# </nav>
# </div>
# <div class="jaf-float-clear"></div>
# </div>
# </div>
# <style type="text/css">@import url(/spazi/jscalendar-1.0/calendar-win2k-1.css);</style>
# <script src="/spazi/jscalendar-1.0/calendar.js" type="text/javascript"></script>
# <script src="/spazi/jscalendar-1.0/lang/calendar-IT.js" type="text/javascript"></script>
# <script src="/spazi/jscalendar-1.0/calendar-setup.js" type="text/javascript"></script>
# <table class="TablePage" style="border-spacing: 0;border-collapse: collapse;">
# <tr class="TrPage">
# <script type="text/javascript">var jaf_js_LANG = 'IT';</script>
# <td class="LeftBar" style="width:15%;">
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Funzioni disponibili</th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_home=evento&amp;jaf_currentWFID=main" title="Home">Home</a></td></tr>
# </table>
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Ricerche disponibili</th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_ricerca_aula=evento&amp;jaf_currentWFID=main" title="Ricerca aula">Ricerca aula</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_ricerca_aule_libere=evento&amp;jaf_currentWFID=main" title="Ricerca aule libere">Ricerca aule libere</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_giornaliera=evento&amp;jaf_currentWFID=main" title="Visualizzazione situazione giornaliera aule">Visualizzazione situazione giornaliera aule</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/OccupazioniGiornoEsatto.do?evn_occupante=evento&amp;jaf_currentWFID=main" title="Ricerca prenotazioni">Ricerca prenotazioni</a></td></tr>
# </table>
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Collegamenti utili  </th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="https://www.polimi.it/orari-campus" title="Orari apertura edifici e campus">Orari apertura edifici e campus</a></td></tr>
# </table>
# <br/>
# <br/>
# <table class="TableOut LegendaTag" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="Head"><span class="HeadText">Attenzione</span></td></tr>
# <tr class="legend-row"><td class="legend-item">
# 			La disponibilità delle aule convegni e dipartimentali potrebbe non essere aggiornata.
# 		</td></tr>
# <tr><td></td></tr>
# </table>
# </td>
# <td class="CenterBar">
# <form action="OccupazioniGiornoEsatto.do">
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Visualizzazioni occupazioni del giorno</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
#
# 				Dove  <span style="font-size: smaller">*</span>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <select id="csic" name="csic">
# <option class="" selected="selected" value="tutte">
# Non specificato
# </option>
# <option class="" value="COE">
# Como
# </option>
# <option class="" value="COE04">
# Como - Via Anzani
# </option>
# <option class="" value="COE02">
# Como - Via Castelnuovo
# </option>
# <option class="" value="COE08">
# Como - Via Zezio
# </option>
# <option class="" value="CRG">
# Cremona
# </option>
# <option class="" value="CRG01">
# Cremona - Via Sesto
# </option>
# <option class="" value="CRG02">
# Cremona - ex Caserma Manfredini
# </option>
# <option class="" value="GEM">
# Genova
# </option>
# <option class="" value="GEM01">
# Genova - Punta Nave
# </option>
# <option class="" value="GEM02">
# Genova - Via delle Fabbriche
# </option>
# <option class="" value="LCF">
# Lecco
# </option>
# <option class="" value="LCF07">
# Lecco - Residenza Loos
# </option>
# <option class="" value="LCF04">
# Lecco - Via Ghislanzoni
# </option>
# <option class="" value="MNI">
# Mantova
# </option>
# <option class="" value="MNI01">
# Mantova - Via Scarsellini 15
# </option>
# <option class="" value="MNI02">
# Mantova - Via Scarsellini 2
# </option>
# <option class="" selected="selected" value="MIB">
# Milano Bovisa
# </option>
# <option class="" value="MIB02">
# Milano Bovisa - Via Durando
# </option>
# <option class="" value="MIB01">
# Milano Bovisa - Via La Masa
# </option>
# <option class="" value="MIA">
# Milano Città Studi
# </option>
# <option class="" value="MIA11">
# Milano Città Studi - Piazza Leonardo da Vinci 26
# </option>
# <option class="" value="MIA01">
# Milano Città Studi - Piazza Leonardo da Vinci 32
# </option>
# <option class="" value="MIA03">
# Milano Città Studi - Via Bassini
# </option>
# <option class="" value="MIA02">
# Milano Città Studi - Via Bonardi
# </option>
# <option class="" value="MIA06">
# Milano Città Studi - Via Colombo 40
# </option>
# <option class="" value="MIA07">
# Milano Città Studi - Via Colombo 81
# </option>
# <option class="" value="MIA14">
# Milano Città Studi - Via Golgi 20
# </option>
# <option class="" value="MIA04">
# Milano Città Studi - Via Golgi 40
# </option>
# <option class="" value="MIA05">
# Milano Città Studi - Via Mancinelli
# </option>
# <option class="" value="MIA15">
# Milano Città Studi - Via Pascoli 70
# </option>
# <option class="" value="MIA09">
# Milano Città Studi - Viale Romagna
# </option>
# <option class="" value="MIF">
# Milano Tortona
# </option>
# <option class="" value="MIF01">
# Milano Tortona - Tortona 37
# </option>
# <option class="" value="PCL">
# Piacenza
# </option>
# <option class="" value="PCL04">
# Piacenza - Via Scalabrini 113
# </option>
# <option class="" value="PCL01">
# Piacenza - Via Scalabrini 76
# </option>
# <option class="" value="MIC">
# Servizi
# </option>
# <option class="" value="MIC09">
# Servizi - Off Campus
# </option>
# <option class="" value="MIC03">
# Servizi - Residenza Einstein
# </option>
# <option class="" value="MIC04">
# Servizi - Residenza Marie Curie
# </option>
# <option class="" value="MIC10">
# Servizi - Residenza Newton
# </option>
# <option class="" value="MIC01">
# Servizi - Residenza Pareto
# </option>
# <option class="" value="MID">
# Sesto Ulteriano
# </option>
# <option class="" value="MID01">
# Sesto Ulteriano - Via Calabria
# </option>
# </select>
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
#
# 				Categoria aula
# 				</td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <select name="categoria" size="1">
# <option value="tutte">Non specificato</option>
# <option value="C">AULA CONVEGNI</option>
# <option value="D">AULA DIDATTICA</option>
# <option value="P">AULA DIPARTIMENTALE</option>
# <option value="M">AULA MAGNA</option>
# <option value="T">AULA MASTER</option>
# <option value="A">AULA STUDIO</option>
# <option value="S">LABORATORIO</option>
# <option value="L">LABORATORIO DIDATTICO</option>
# <option value="E">SPAZIO ESPOSITIVO</option>
# </select>
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
#
# 				Tipologia aula
# 			</td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <select name="tipologia" size="1">
# <option value="tutte">Non specificato</option>
# <option value="A">ALTRO</option>
# <option value="D">DISEGNO</option>
# <option value="N">INFORMATIZZATA</option>
# <option value="F">PLATEA FRONTALE</option>
# <option value="S">STUDIO INDIVIDUALE</option>
# </select>
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
#
# 						Giorno <span style="font-size: smaller">*</span>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <script type="text/javascript">// Prepare to show a date picker linked to three select controls
# function readLinked(input, datepicker) {
# if(!datepicker || !datepicker.settings.dateFormat)return;
# chiave = input.id;
# if(!$('#'+chiave+'_day').val() || !$('#'+chiave+'_month').val() || !$('#'+chiave+'_year').val())
# return;
# var parsed = $.datepicker.parseDate('dd/mm/yy',$('#'+chiave+'_day').val() + '/' +
# $('#'+chiave+'_month').val() + '/' + $('#'+chiave+'_year').val());
# var formattata = $.datepicker.formatDate(datepicker.settings.dateFormat, parsed);
# $('#'+chiave).val(formattata);
# return {};
# }
#
# // Update three select controls to match a date picker selection
# function updateLinked(date) {
#    updateLinked2(date,this.id)
# }
# function updateLinked2(date, chiave) {
# if (date.substring(1,2)=='/') date='0'+date;if (date.substring(4,5)=='/') date=date.substring(0,3)+'0'+date.substring(3,10);if (date.substring(0, 1)=='0')
#   $('#'+chiave+'_day').val(date.substring(1, 2));
# else
#   $('#'+chiave+'_day').val(date.substring(0, 2));
# $('#'+chiave+'_year').val(date.substring(6, 10));
# mese = date.substring(3, 5);
# meseDigit = date.substring(3, 4);
# if (meseDigit=='0')
# $('#'+chiave+'_month').val(date.substring(4, 5));
# else
# $('#'+chiave+'_month').val(date.substring(3, 5));
# $('#'+chiave+'_day').focusout();
# $('#'+chiave+'_month').focusout();
# $('#'+chiave+'_year').focusout();
#
# }
# </script> <select id="giorno_day" name="giorno_day">
# <option value=""> </option>
# <option selected="" value="1">
# 01</option>
# <option value="2">
# 02</option>
# <option value="3">
# 03</option>
# <option value="4">
# 04</option>
# <option value="5">
# 05</option>
# <option value="6">
# 06</option>
# <option value="7">
# 07</option>
# <option value="8">
# 08</option>
# <option value="9">
# 09</option>
# <option value="10">
# 10</option>
# <option value="11">
# 11</option>
# <option value="12">
# 12</option>
# <option value="13">
# 13</option>
# <option value="14">
# 14</option>
# <option value="15">
# 15</option>
# <option value="16">
# 16</option>
# <option value="17">
# 17</option>
# <option value="18">
# 18</option>
# <option value="19">
# 19</option>
# <option value="20">
# 20</option>
# <option value="21">
# 21</option>
# <option value="22">
# 22</option>
# <option value="23">
# 23</option>
# <option value="24">
# 24</option>
# <option value="25">
# 25</option>
# <option value="26">
# 26</option>
# <option value="27">
# 27</option>
# <option value="28">
# 28</option>
# <option value="29">
# 29</option>
# <option value="30">
# 30</option>
# <option value="31">
# 31</option>
# </select>
# <select id="giorno_month" name="giorno_month">
# <option value=""> </option>
# <option value="1">
# Gennaio</option>
# <option selected="" value="2">
# Febbraio</option>
# <option value="3">
# Marzo</option>
# <option value="4">
# Aprile</option>
# <option value="5">
# Maggio</option>
# <option value="6">
# Giugno</option>
# <option value="7">
# Luglio</option>
# <option value="8">
# Agosto</option>
# <option value="9">
# Settembre</option>
# <option value="10">
# Ottobre</option>
# <option value="11">
# Novembre</option>
# <option value="12">
# Dicembre</option>
# </select>
# <select id="giorno_year" name="giorno_year">
# <option value=""> </option><option value="2020">
# 2020</option>
# <option value="2021">
# 2021</option>
# <option value="2022">
# 2022</option>
# <option value="2023">
# 2023</option>
# <option value="2024">
# 2024</option>
# <option selected="" value="2025">
# 2025</option>
# <option value="2026">
# 2026</option>
# <option value="2027">
# 2027</option>
# <option value="2028">
# 2028</option>
# <option value="2029">
# 2029</option>
# <option value="2030">
# 2030</option>
# </select>
# <input name="jaf_giorno_date_format" type="hidden" value="dd/MM/yyyy"/><input disabled="disabled" id="giorno" name="giorno" type="hidden"/><script type="text/javascript">$(document).ready(function(){
# $("#giorno").datepicker(
#  $.extend({},
#  $.datepicker.regional['it'],
#  {
# yearRange: '2020:2030', minDate:new Date(2020, 0 , 1)
#   , maxDate:new Date(2030, 11, 31)
#   ,
# changeYear: true, constrainInput: true, duration: '' ,
# beforeShow: readLinked ,
# onSelect: updateLinked ,
# showOn: 'button' }
#  )
# );
# });
# </script>
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard2 jaf-card-element" colspan="2" rowspan="1" style="width: 100%">
# <span style="font-size: smaller">* Campo obbligatorio</span>
# </td>
# </tr>
# </table>
# <button class="jaf-btn-big" name="evn_visualizza" type="submit">
# 			Visualizza occupazioni
# 		</button>
# <button class="jaf-btn-big" name="evn_init" type="submit">
# 			Pulisci parametri
# 		</button>
# </form>
# <br/>
# <script language="JavaScript">
# browsername=navigator.appName;
# if (browsername.indexOf("Netscape")!=-1) {browsername="NS"}
# else
# {if (browsername.indexOf("Microsoft")!=-1) {browsername="MSIE"}
# else {browsername="N/A"}};
#
# if (browsername=="MSIE")
# 	document.write('<link rel="stylesheet" type="text/css" href="/spazi/table-IE.css">');
# else
# 	document.write('<link rel="stylesheet" type="text/css" href="/spazi/table-MOZ.css">');
#
# </script>
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Occupazioni</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="MatriceOccupazioni jaf-card-element" colspan="1" rowspan="1">
# <div class="tableContainer" id="tableContainer">
# <table class="scrollTable" padding="0" spacing="0" style="table-layout: fixed; width: 100%;">
# <tbody class="scrollContent">
# <tr class="normalRow">
# <th class="data" style="width: 8%"></th>
# <th class="dove" style="width: 8%"></th><th class="empty" colspan="52"></th></tr>
# <tr><td class="innerEdificio" colspan="54">Milano Bovisa - Via Durando - Edificio B1 - Piano Terzo</td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=4517" title="Milano Bovisa - Via Durando - Edificio B1 - Piano Terzo"> F.LLI CASTIGLIONI  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr><td class="innerEdificio" colspan="54">Milano Bovisa - Via Durando - Edificio B2 - Piano Terra</td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><t ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=2092" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terra"> B2.0.1 - D.I.  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr><td class="innerEdificio" colspan="54">Milano Bovisa - Via Durando - Edificio B2 - Piano Primo</td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><t ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=1301" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.10  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=2108" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.11  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=1906" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.12  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=1905" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.13  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=2107" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.14  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=988" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.15  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td></tr><tr class="norma ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=4618" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.16  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=1898" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.1  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=1903" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.2  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=987" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.3  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=2106" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.5  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=984" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.6  </a>
# ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=4745" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Terra"> AULA CARASSA E DADDA  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr><td class="innerEdificio" colspan="54">Milano Bovisa - Via La Masa - Edificio BL28 - Piano Primo</td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td> ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=4741" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Primo"> BL.28.1.1  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=4742" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Primo"> BL.28.1.2  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr><td class="innerEdificio" colspan="54">Milano Bovisa - Via La Masa - Edificio BL28 - Piano Secondo</td></tr><tr><td class="innerDataDove">Data</td><td class="innerDataDove">Dove</td><td class="innerOrario" colspan="2"></td><td class="innerOrario" colspan="4">09:00</td><td class="innerOrario" colspan="4">10:00</td><td class="innerOrario" colspan="4">11:00</td><td class="innerOrario" colspan="4">12:00</td><td class="innerOrario" colspan="4">13:00</td><td class="innerOrario" colspan="4">14:00</td><td class="innerOrario" colspan="4">15:00</td><td class="innerOrario" colspan="4">16:00</td><td class="innerOrario" colspan="4">17:00</td><td class="innerOrario" colspan="4">18:00</td><td class="innerOrario" colspan="4">19:00</td><td class="innerOrario" colspan="4">20:00</td><td class="innerOrario" colspan="2"></td></tr><tr><td class="innerGiorno" colspan="2"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></td><td class="empty"></td><td class="empty"></td><td class="riferimento_orario_ultima"></td><td class="riferimento_orario_prima" style="height:10"></t ...
# <a href="Aula.do?evn_init=espandi&amp;idaula=4743" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Secondo"> BL.28.2.1  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr><tr class="normalRow"><td class="data" rowspan="1"> Sab 01/02/2025 </td><td class="dove" rowspan="1">
# <a href="Aula.do?evn_init=espandi&amp;idaula=4744" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Secondo"> BL.28.2.2  </a>
# </td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td><td class="empty_prima"></td><td class="empty"></td><td class="empty"></td><td class="empty"></td></tr></tbody></table></div></td></tr></table>
# </td>
# </tr></table>
# <table class="polifooter">
# <tfoot class="tfoot-tablePage">
# <tr>
# <td>
# <div class="jaf-text-align-left">
# 	   				 spazi v. 1.7.12 / 1.7.12
# 	   			</div>
# </td>
# <td>
# <div class="jaf-text-align-center">
# 					Area Servizi ICT
#     			</div>
# </td>
# <td>
# <div class="jaf-text-align-right" id="div-tfoot-tablePage-centerBar">
# </div>
# </td>
# </tr>
# </tfoot>
# </table>
# </div>
# </body>
# </html>

# %%
classrooms = soup.find("td", {"class": "MatriceOccupazioni"}).find_all(
    "td", {"class": "dove"}
)
classrooms
# Out:
# [<td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4517" title="Milano Bovisa - Via Durando - Edificio B1 - Piano Terzo"> F.LLI CASTIGLIONI  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=2092" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terra"> B2.0.1 - D.I.  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1301" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.10  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=2108" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.11  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1906" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.12  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1905" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.13  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=2107" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.14  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=988" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.15  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4618" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.16  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1898" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1903" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=987" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=2106" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=984" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=983" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.8  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1899" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Primo"> B2.1.9  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1907" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.10  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1917" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.11  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4616" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.12  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1916" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.13  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1915" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.14  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4619" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.15  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1914" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1913" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1912" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1911" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4617" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1910" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1909" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.7  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1908" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.8  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4620" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Secondo"> B2.2.9  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1956" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terzo"> B2.3.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1955" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terzo"> B2.3.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1954" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terzo"> B2.3.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1953" title="Milano Bovisa - Via Durando - Edificio B2 - Piano Terzo"> B2.3.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4693" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4694" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4855" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4856" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4699" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4700" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Secondo"> B6.2.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4701" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Terzo"> B6.3.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4703" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Terzo"> B6.3.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4861" title="Milano Bovisa - Via Durando - Edificio B6 - Piano Terzo"> B6.3.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4862" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.10  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4863" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.11  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4864" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.12  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4778" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4779" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4780" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4781" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4782" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4783" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=5072" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.7  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4784" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.8  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=5073" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra"> B8 0.9  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4785" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra Soppalco"> B8 1.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=5074" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra Soppalco"> B8 1.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4786" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra Soppalco"> B8 1.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=5075" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Terra Soppalco"> B8 1.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4787" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Primo"> B8 2.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4788" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Primo"> B8 2.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4789" title="Milano Bovisa - Via Durando - Edificio B8 - Piano Primo"> B8 2.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=5014" title="Milano Bovisa - Via Durando - Edificio B9 - Piano Terra"> CARLO DE CARLI  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=79" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.01  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=80" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.02  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=81" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.03  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=82" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.04 VIRTUAL LAB  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=83" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.05 - D.I.  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=84" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.06  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=85" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.07  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=87" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.08  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=86" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Terra"> L.09  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=89" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Primo"> L.11  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1781" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Primo"> L.12  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1782" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Primo"> L.13  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=641" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Primo"> L.14  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1862" title="Milano Bovisa - Via La Masa - Edificio B12 - Piano Primo"> L.15  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=1783" title="Milano Bovisa - Via La Masa - Edificio B15 - Piano Terra"> LM.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=628" title="Milano Bovisa - Via La Masa - Edificio B15 - Piano Terra"> LM.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=629" title="Milano Bovisa - Via La Masa - Edificio B15 - Piano Terra"> LM.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=630" title="Milano Bovisa - Via La Masa - Edificio B15 - Piano Terra"> LM.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=631" title="Milano Bovisa - Via La Masa - Edificio B15 - Piano Terra"> LM.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4668" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> ATRIO P.T. - ED. BL.27  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4550" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> BL.27.0.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4551" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> BL.27.0.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4552" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> BL.27.0.7  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4553" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> BL.27.0.8  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4670" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> CORRIDOIO DX P.T. - ED. BL 27   </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4669" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Terra"> CORRIDOIO SX P.T. - ED. BL 27  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4671" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> ATRIO 1° PIANO - ED. BL.27  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4546" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.0.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4547" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.0.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4548" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.0.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4549" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.0.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4554" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4556" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4557" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.3  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4558" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.4  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4559" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.5  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4560" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.6  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4561" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.7  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4562" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> BL.27.1.8  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4673" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> CORRIDOIO DX 1° P. - ED. BL.27  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4672" title="Milano Bovisa - Via La Masa - Edificio BL27 - Piano Primo"> CORRIDOIO SX 1° P. - ED. BL.27  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4745" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Terra"> AULA CARASSA E DADDA  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4741" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Primo"> BL.28.1.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4742" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Primo"> BL.28.1.2  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4743" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Secondo"> BL.28.2.1  </a>
#  </td>,
#  <td class="dove" rowspan="1">
#  <a href="Aula.do?evn_init=espandi&amp;idaula=4744" title="Milano Bovisa - Via La Masa - Edificio BL28 - Piano Secondo"> BL.28.2.2  </a>
#  </td>]

# %%
classroom_url = urljoin(URL, classrooms[0].find("a")["href"])
classroom_url
# Out:
# 'https://www7.ceda.polimi.it/spazi/spazi/controller/Aula.do?evn_init=espandi&idaula=4517'

# %%
classroom_soup = BeautifulSoup(requests.get(classroom_url).text, "html.parser")
classroom_soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js">
# <head>
# <title>Dettagli Aula</title>
# <link href="https://webcommons.polimi.it/webcommons/assets/ateneo2014.css.jsp?v=5&amp;lang=it&amp;dt_version=1.10" rel="stylesheet" type="text/css"/>
# <link href="https://webcommons.polimi.it/webcommons/ajax/libs/jqueryui/1.12.1/themes/polij.css.jsp?v=5&amp;lang=it" rel="stylesheet" type="text/css"/>
# <link href="https://webcommons.polimi.it/webcommons/assets/desktop.css.jsp?v=5&amp;lang=it" rel="stylesheet" type="text/css"/>
# <link href="/spazi/assets/css/base.css?__load_ts=1737140432539" rel="stylesheet" type="text/css"/>
# <script src="https://webcommons.polimi.it/webcommons/ajax/libs/jqueryui/1.12.1/ui.js.jsp?v=5&amp;lang=it&amp;dt_version=1.10" type="text/javascript"></script>
# <script src="https://webcommons.polimi.it/webcommons/ajax/libs/desktop.js.jsp?v=5&amp;lang=it" type="text/javascript"></script>
# <script type="text/javascript">
# 	$(document).ready(function(){
# 		$('#loading').remove();
# 	});
# </script>
# </head>
# <body>
# <div id="jafBodyContainer">
# <div id="polijPageHeader">
# <table id="poliheader">
# <tr>
# <td class="jaf-text-align-left td-logo-polimi">
# <a href="http://www.polimi.it" title="polimi.it">
# <img alt="logo-polimi" class="logo-polimi" src="https://webcommons.polimi.it/webcommons/assets/logo_polimi_testo.png"/>
# </a>
# <div id="loading">
# <strong>La pagina è in caricamento...</strong><div class="jaf-loading-bar thin" style="max-width: 200px;"></div>
# </div>
# </td>
# <td class="jaf-text-align-center info-DB">
# </td>
# <td class="jaf-text-align-right info-utente">
# </td>
# </tr>
# </table>
# <div id="policontext">
# <nav class="nomeApp policontext-link" style="float: left; margin: auto 1em;">
# 		 spazi
# 	</nav>
# <div class="policontext-link">
# <nav>
# <a href="/spazi/spazi/controller/Aula.do?evn_jaf_cambio_lingua=event&amp;lang=EN&amp;screenName=/pagine/aule/aula.jsp&amp;freezecount=true&amp;jaf_currentWFID=main&amp;polij_step=0&amp;__pj0=0&amp;__pj1=fa0e079a2fd61c129be3978dcab44451" title="English"><img alt="English" src="//webcommons.polimi.it/webcommons/assets/english.gif" title="English"/></a>
# </nav>
# </div>
# <div class="jaf-float-clear"></div>
# </div>
# </div>
# <table class="TablePage" style="border-spacing: 0;border-collapse: collapse;">
# <tr class="TrPage">
# <script type="text/javascript">var jaf_js_LANG = 'IT';</script>
# <td class="LeftBar" style="width:15%;">
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Funzioni disponibili</th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/Aula.do?evn_home=evento&amp;jaf_currentWFID=main" title="Home">Home</a></td></tr>
# </table>
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Ricerche disponibili</th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/Aula.do?evn_ricerca_aula=evento&amp;jaf_currentWFID=main" title="Ricerca aula">Ricerca aula</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/Aula.do?evn_ricerca_aule_libere=evento&amp;jaf_currentWFID=main" title="Ricerca aule libere">Ricerca aule libere</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/Aula.do?evn_giornaliera=evento&amp;jaf_currentWFID=main" title="Visualizzazione situazione giornaliera aule">Visualizzazione situazione giornaliera aule</a></td></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="/spazi/spazi/controller/Aula.do?evn_occupante=evento&amp;jaf_currentWFID=main" title="Ricerca prenotazioni">Ricerca prenotazioni</a></td></tr>
# </table>
# <br/>
# <table class="TableCommand" style="border-spacing:0; border-collapse:collapse;"><tr><th class="HeadCommand">Collegamenti utili  </th></tr>
# <tr><td class="BodyFunction"><a class="linkFunction" href="https://www.polimi.it/orari-campus" title="Orari apertura edifici e campus">Orari apertura edifici e campus</a></td></tr>
# </table>
# <br/>
# <br/>
# <table class="TableOut LegendaTag" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="Head"><span class="HeadText">Attenzione</span></td></tr>
# <tr class="legend-row"><td class="legend-item">
# 			La disponibilità delle aule convegni e dipartimentali potrebbe non essere aggiornata.
# 		</td></tr>
# <tr><td></td></tr>
# </table>
# </td>
# <td class="CenterBar">
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Ubicazione</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 5%">
# <a class="Link" href="https://aunicalogin.polimi.it/aunicalogin/aunicalogin.jsp?lang=IT&amp;id_servizio=498&amp;id_aula=4517&amp;polij_step=0&amp;__pj0=0&amp;__pj1=2b958bebf0327262f1b82ab74a69b394" target="_blank"><img alt="Vedi l'aula sulla mappa interattiva" border="0" src="/spazi/images/mappa.gif"/> </a>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <a class="Link" href="https://aunicalogin.polimi.it/aunicalogin/aunicalogin.jsp?lang=IT&amp;id_servizio=498&amp;id_aula=4517&amp;polij_step=0&amp;__pj0=0&amp;__pj1=2b958bebf0327262f1b82ab74a69b394">Vedi l'aula sulla mappa interattiva</a>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 5%">
# <a class="Link" href="https://aunicalogin.polimi.it/aunicalogin/aunicalogin.jsp?lang=IT&amp;id_servizio=590&amp;id_aula=4517&amp;polij_step=0&amp;__pj0=0&amp;__pj1=c2b3fcc1dc57e1e210646252df9f704a" target="_blank">
# <img alt="Come raggiungere l'aula (versione stampabile)" border="0" src="/spazi/images/stampa.jpg"/>
# </a>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
# <a class="Link" href="https://aunicalogin.polimi.it/aunicalogin/aunicalogin.jsp?lang=IT&amp;id_servizio=590&amp;id_aula=4517&amp;polij_step=0&amp;__pj0=0&amp;__pj1=c2b3fcc1dc57e1e210646252df9f704a" target="_blank">Come raggiungere l'aula (versione stampabile)</a>
# </td>
# </tr>
# </table>
# <br>
# <br>
# <div class="tabs polij_tabs" id="tab24699">
# <ul><li><a href="#tab24699-0">Dati aula</a></li><li><a href="#tab24699-1">Accessi, percorsi e foto</a></li><li><a href="#tab24699-2">Allestimenti, software e altre informazioni disponibili</a></li></ul><div id="tab24699-0">
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Sigla</em>
# <br/> F.LLI CASTIGLIONI
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Denominazione</em>
# <br/>
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Descrizione</em>
# <br/>
# 		</td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Categoria</em>
# <br/> AULA DIDATTICA
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Tipologia</em>
# <br/> DISEGNO
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Dove</em>
# <br/> Milano Bovisa - Via Durando
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Edificio</em>
# <br/> Edificio B1 - Biblioteca
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Indirizzo</em>
# <br/> Via Candiani, 72 - 20158 - Milano (MI)
# 		</td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Dipartimento</em>
# <br/> -
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Codice vano</em>
# <br/> MIB0212003026
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# </td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Capienza</em>
# <br/> 134
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Tipo postazioni</em>
# <br/> TAVOLI DA DISEGNO
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Numero postazioni</em>
# <br/>
#
# 				67
#
# 		</td>
# </tr>
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 33%">
# <em>Postazioni per studenti disabili</em>
# <br/>
#
# 				1
#
# 		</td>
# <td class="ElementInfoCard1 jaf-card-element" colspan="2" rowspan="1" style="width: 66%">
# <strong>Aula dotata di postazione ergonomica per studenti con disabilità</strong>
# </td>
# </tr>
# </table>
# </div><noscript><br/><br/></noscript><div id="tab24699-1">
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Accesso</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1">
# <i>Edificio</i>
# <br/> L'edifico presenta tre ingressi. L'accesso all'edificio consigliato è dalla rampa proveniente dal vicino edificio N. E' possibile contattare la portineria interna al tel 02 -23997180. L'accesso ai diversi piani avviene tramite ascensore e/o scala. Per utilizzare l'ascensore è necessario contattare la portineria interna, essendo riservato al personale e condizionato da chiave. La circolazione interna è agevole. Sono presenti servizi igienici accessibili.
# 		</td>
# </tr>
# <tr>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1">
# <i>Campus</i>
# <br/> L'accesso principale e carabile del Campus è quello du via Durando, 10. Nel Campus sono presenti parcheggi riservati per i possessori di contrassegno. La circolazione in piano all'interno del Campus è agevole. Sono presenti scivoli di raccordo tra marciapiede e sede stradale. Non ci sono percorsi tattili per disabili visivi. Non esistono attrezzature per non vedenti.
# 		</td>
# </tr>
# </table>
# <br/>
# <div class="div-content-table" id="div_table_aula_xPercorsiAccesso">
# <h4 class="titleTableRecordSet">Percorsi</h4>
# <table class="TableDati" id="aula_xPercorsiAccesso">
# <thead>
# <tr class="elenco-campi"><th class="HeadColumn1" width="25%">Partenza</th>
# <th class="HeadColumn1">Descrizione</th>
# </tr>
# </thead>
# <tbody class="TableDati-tbody">
# <tr class="dispari">
# <td class="TestoSXBold Dati1">
#
#
# 		Stazione Milano Centrale
# 	</td>
# <td class="TestoSX Dati1">
#
#
# 		Prendete la Metropolitana Linea 2 (MM2 Linea Verde), direzione Abbiategrasso, e scendete alla stazione di GARIBALDI (seconda fermata); qui, senza uscire dalla Metropolitana, prendete il passante ferroviario in direzione Bovisa e scendete alla stazione di MILANO BOVISA (seconda fermata). Usciti dalla stazione svoltate a sinistra e scendete la scalinata: vi trovate in piazza E. Alfieri (con al centro un parcheggio). Attraversate la piazza mantenendovi sul lato destro, quindi proseguite dritto imboccando via G. Candiani. L'ingresso del Politecnico si trova sulla sinistra al civico 72. Il solo edificio B10 è raggiungibile da via Durando 38/A.
# 	</td>
# </tr>
# <tr class="pari">
# <td class="TestoSXBold Dati1">
#
#
# 		Stazione Milano Cadorna
# 	</td>
# <td class="TestoSX Dati1">
#
#
# 		Raggiungete in treno la stazione di MILANO BOVISA (tutti i treni in partenza dalla stazione di Milano Cadorna, ad eccezione del Malpensa Express, fermano a Bovisa). Usciti dalla stazione svoltate a sinistra e scendete la scalinata: vi trovate in piazza E. Alfieri (con al centro un parcheggio). Attraversate la piazza mantenendovi sul lato destro, quindi proseguite dritto imboccando via G. Candiani. L'ingresso del Politecnico si trova sulla sinistra al civico 72. Il solo edificio B10 è raggiungibile da via Durando 38/A.
# 	</td>
# </tr></tbody>
# </table>
# <div class="div-float-clear"></div>
# </div>
# <br/>
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Foto</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard1 TestoSX jaf-card-element" colspan="1" rowspan="1">
# <img alt="F.LLI CASTIGLIONI" border="0" height="300px" src="https://docmanager.polimi.it/documentimanager/downloadHttps?id_documento=128333&amp;cah=025930&amp;__pj0=0&amp;__pj1=ea1f433058a39efb84b2bbdec8756594" width="450px"/>
# </td>
# </tr>
# </table>
# </div><noscript><br/><br/></noscript><div id="tab24699-2">
# <div class="div-content-table" id="div_table_aula_xproprietaPubblicabili_auleColl">
# <h4 class="titleTableRecordSet">Allestimenti</h4>
# <table class="TableDati" id="aula_xproprietaPubblicabili_auleColl">
# <thead>
# <!-- Gruppo -->
# <!-- Proprietà -->
# <!-- Valore -->
# <tr class="elenco-campi"><th class="HeadColumn1">Gruppo</th>
# <th class="HeadColumn1">Proprietà</th>
# <th class="HeadColumn1">Valore</th>
# </tr>
# </thead>
# <tbody class="TableDati-tbody">
# <tr class="dispari">
# <!-- Gruppo -->
# <td class="Dati1">
#
# 		ATTREZZATURE
#     </td>
# <!-- Proprietà -->
# <td class="Dati1">
#
# 		Radio microfono
# 	</td>
# <!-- Valore -->
# <td class="Dati1">
#
# 		SI
# 	</td>
# </tr>
# <tr class="pari">
# <!-- Gruppo -->
# <td class="Dati1">
#
# 		ATTREZZATURE
#     </td>
# <!-- Proprietà -->
# <td class="Dati1">
#
# 		Oscurabile
# 	</td>
# <!-- Valore -->
# <td class="Dati1">
#
# 		SI
# 	</td>
# </tr>
# <tr class="dispari">
# <!-- Gruppo -->
# <td class="Dati1">
#
# 		ATTREZZATURE
#     </td>
# <!-- Proprietà -->
# <td class="Dati1">
#
# 		Cattedra cablata
# 	</td>
# <!-- Valore -->
# <td class="Dati1">
#
# 		SI
# 	</td>
# </tr>
# <tr class="pari">
# <!-- Gruppo -->
# <td class="Dati1">
#
# 		ATTREZZATURE
#     </td>
# <!-- Proprietà -->
# <td class="Dati1">
#
# 		Video proiettore con PC
# 	</td>
# <!-- Valore -->
# <td class="Dati1">
#
# 		SI
# 	</td>
# </tr>
# <tr class="dispari">
# <!-- Gruppo -->
# <td class="Dati1">
#
# 		ATTREZZATURE
#     </td>
# <!-- Proprietà -->
# <td class="Dati1">
#
# 		Microfono
# 	</td>
# <!-- Valore -->
# <td class="Dati1">
#
# 		SI
# 	</td>
# </tr></tbody>
# </table>
# <div class="div-float-clear"></div>
# </div>
# <br/>
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Software installati</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1">
# <div style="overflow:auto; max-height: 250px">
# <div id="div_table_sw_installato">
# <table class="TableDati" id="sw_installato"><thead></thead><tbody class="TableDati-tbody"><tr><td class="MsgEmptyClass" colspan="0" style="width:100%">Nessun software installato</td></tr></tbody>
# </table>
# <div class="div-float-clear"></div>
# </div>
# </div>
# </td>
# </tr>
# </table>
# <br/>
# <div id="div_table_aula_altreRisorse_auleColl">
# <h4 class="titleTableRecordSet">Ulteriori informazioni disponibili in rete</h4>
# <table class="TableDati" id="aula_altreRisorse_auleColl"><thead></thead><tbody class="TableDati-tbody"><tr><td class="MsgEmptyClass" colspan="0" style="width:100%">Nessuna ulteriore informazione disponibile</td></tr></tbody>
# </table>
# <div class="div-float-clear"></div>
# </div>
# </div><noscript><br/><br/></noscript></div>
# <script type="text/javascript">
# 	$(document).ready(function () {
# 		$('#tab24699').tabs({
# 				dummy: 0});
# 		jaf_tabsactivate('tab24699');
# 	});
# </script>
# <br>
# <form action="/spazi/spazi/controller/Aula.do?jaf_currentWFID=main" class="jaf-form jaf-desktop-form" enctype="multipart/form-data" id="occupaz_form" method="POST" name="occupaz_form">
# <input name="spazi___model___formbean___DateOccupazForm___postBack" type="hidden" value="true"/><input name="spazi___model___formbean___DateOccupazForm___formMode" type="hidden" value="FILTER"/>
# <input name="idaula" type="hidden" value="4517"/>
# <table class="BodyInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="TitleInfoCard">Eventi occupanti l'aula</td>
# </tr>
# </table>
# <table class="BoxInfoCard" style="border-spacing: 0;border-collapse: collapse;">
# <tr>
# <td class="ElementInfoCard1 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
# <label for="spazi___model___formbean___DateOccupazForm___fromData">
# 							Dal
# 						 *</label>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <script type="text/javascript">// Prepare to show a date picker linked to three select controls
# function readLinked(input, datepicker) {
# if(!datepicker || !datepicker.settings.dateFormat)return;
# chiave = input.id;
# if(!$('#'+chiave+'_day').val() || !$('#'+chiave+'_month').val() || !$('#'+chiave+'_year').val())
# return;
# var parsed = $.datepicker.parseDate('dd/mm/yy',$('#'+chiave+'_day').val() + '/' +
# $('#'+chiave+'_month').val() + '/' + $('#'+chiave+'_year').val());
# var formattata = $.datepicker.formatDate(datepicker.settings.dateFormat, parsed);
# $('#'+chiave).val(formattata);
# return {};
# }
#
# // Update three select controls to match a date picker selection
# function updateLinked(date) {
#    updateLinked2(date,this.id)
# }
# function updateLinked2(date, chiave) {
# if (date.substring(1,2)=='/') date='0'+date;if (date.substring(4,5)=='/') date=date.substring(0,3)+'0'+date.substring(3,10);if (date.substring(0, 1)=='0')
#   $('#'+chiave+'_day').val(date.substring(1, 2));
# else
#   $('#'+chiave+'_day').val(date.substring(0, 2));
# $('#'+chiave+'_year').val(date.substring(6, 10));
# mese = date.substring(3, 5);
# meseDigit = date.substring(3, 4);
# if (meseDigit=='0')
# $('#'+chiave+'_month').val(date.substring(4, 5));
# else
# $('#'+chiave+'_month').val(date.substring(3, 5));
# $('#'+chiave+'_day').focusout();
# $('#'+chiave+'_month').focusout();
# $('#'+chiave+'_year').focusout();
#
# }
# </script> <select data-jaf-field-name="fromData_day" data-jaf-group-name="fromData" id="spazi___model___formbean___DateOccupazForm___fromData_day" name="spazi___model___formbean___DateOccupazForm___fromData_day">
# <option value=""> </option>
# <option selected="" value="1">
# 01</option>
# <option value="2">
# 02</option>
# <option value="3">
# 03</option>
# <option value="4">
# 04</option>
# <option value="5">
# 05</option>
# <option value="6">
# 06</option>
# <option value="7">
# 07</option>
# <option value="8">
# 08</option>
# <option value="9">
# 09</option>
# <option value="10">
# 10</option>
# <option value="11">
# 11</option>
# <option value="12">
# 12</option>
# <option value="13">
# 13</option>
# <option value="14">
# 14</option>
# <option value="15">
# 15</option>
# <option value="16">
# 16</option>
# <option value="17">
# 17</option>
# <option value="18">
# 18</option>
# <option value="19">
# 19</option>
# <option value="20">
# 20</option>
# <option value="21">
# 21</option>
# <option value="22">
# 22</option>
# <option value="23">
# 23</option>
# <option value="24">
# 24</option>
# <option value="25">
# 25</option>
# <option value="26">
# 26</option>
# <option value="27">
# 27</option>
# <option value="28">
# 28</option>
# <option value="29">
# 29</option>
# <option value="30">
# 30</option>
# <option value="31">
# 31</option>
# </select>
# <select data-jaf-field-name="fromData_month" data-jaf-group-name="fromData" id="spazi___model___formbean___DateOccupazForm___fromData_month" name="spazi___model___formbean___DateOccupazForm___fromData_month">
# <option value=""> </option>
# <option value="1">
# Gennaio</option>
# <option selected="" value="2">
# Febbraio</option>
# <option value="3">
# Marzo</option>
# <option value="4">
# Aprile</option>
# <option value="5">
# Maggio</option>
# <option value="6">
# Giugno</option>
# <option value="7">
# Luglio</option>
# <option value="8">
# Agosto</option>
# <option value="9">
# Settembre</option>
# <option value="10">
# Ottobre</option>
# <option value="11">
# Novembre</option>
# <option value="12">
# Dicembre</option>
# </select>
# <select data-jaf-field-name="fromData_year" data-jaf-group-name="fromData" id="spazi___model___formbean___DateOccupazForm___fromData_year" name="spazi___model___formbean___DateOccupazForm___fromData_year">
# <option value=""> </option><option value="2020">
# 2020</option>
# <option value="2021">
# 2021</option>
# <option value="2022">
# 2022</option>
# <option value="2023">
# 2023</option>
# <option value="2024">
# 2024</option>
# <option selected="" value="2025">
# 2025</option>
# <option value="2026">
# 2026</option>
# <option value="2027">
# 2027</option>
# <option value="2028">
# 2028</option>
# <option value="2029">
# 2029</option>
# <option value="2030">
# 2030</option>
# </select>
# <input name="jaf_spazi___model___formbean___DateOccupazForm___fromData_date_format" type="hidden" value="dd/MM/yyyy"><input disabled="disabled" id="spazi___model___formbean___DateOccupazForm___fromData" name="spazi___model___formbean___DateOccupazForm___fromData" type="hidden"/><script type="text/javascript">$(document).ready(function(){
# $("#spazi___model___formbean___DateOccupazForm___fromData").datepicker(
#  $.extend({},
#  $.datepicker.regional['it'],
#  {
# yearRange: '2020:2030', minDate:new Date(2020, 0 , 1)
#   , maxDate:new Date(2030, 11, 31)
#   ,
# changeYear: true, constrainInput: true, duration: '' ,
# beforeShow: readLinked ,
# onSelect: updateLinked ,
# showOn: 'button' }
#  )
# );
# });
# </script> <label class="formValidationErrorMessage" for="spazi___model___formbean___DateOccupazForm___fromData" style="display:none;"></label>
# </input></td>
# </tr>
# <tr>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 30%">
# <label for="spazi___model___formbean___DateOccupazForm___toData">
# 							Al
# 						 *</label>
# </td>
# <td class="ElementInfoCard2 jaf-card-element" colspan="1" rowspan="1" style="width: 60%">
# <select data-jaf-field-name="toData_day" data-jaf-group-name="toData" id="spazi___model___formbean___DateOccupazForm___toData_day" name="spazi___model___formbean___DateOccupazForm___toData_day">
# <option value=""> </option>
# <option value="1">
# 01</option>
# <option value="2">
# 02</option>
# <option value="3">
# 03</option>
# <option value="4">
# 04</option>
# <option value="5">
# 05</option>
# <option value="6">
# 06</option>
# <option value="7">
# 07</option>
# <option value="8">
# 08</option>
# <option value="9">
# 09</option>
# <option value="10">
# 10</option>
# <option value="11">
# 11</option>
# <option value="12">
# 12</option>
# <option value="13">
# 13</option>
# <option value="14">
# 14</option>
# <option value="15">
# 15</option>
# <option selected="" value="16">
# 16</option>
# <option value="17">
# 17</option>
# <option value="18">
# 18</option>
# <option value="19">
# 19</option>
# <option value="20">
# 20</option>
# <option value="21">
# 21</option>
# <option value="22">
# 22</option>
# <option value="23">
# 23</option>
# <option value="24">
# 24</option>
# <option value="25">
# 25</option>
# <option value="26">
# 26</option>
# <option value="27">
# 27</option>
# <option value="28">
# 28</option>
# <option value="29">
# 29</option>
# <option value="30">
# 30</option>
# <option value="31">
# 31</option>
# </select>
# <select data-jaf-field-name="toData_month" data-jaf-group-name="toData" id="spazi___model___formbean___DateOccupazForm___toData_month" name="spazi___model___formbean___DateOccupazForm___toData_month">
# <option value=""> </option>
# <option value="1">
# Gennaio</option>
# <option selected="" value="2">
# Febbraio</option>
# <option value="3">
# Marzo</option>
# <option value="4">
# Aprile</option>
# <option value="5">
# Maggio</option>
# <option value="6">
# Giugno</option>
# <option value="7">
# Luglio</option>
# <option value="8">
# Agosto</option>
# <option value="9">
# Settembre</option>
# <option value="10">
# Ottobre</option>
# <option value="11">
# Novembre</option>
# <option value="12">
# Dicembre</option>
# </select>
# <select data-jaf-field-name="toData_year" data-jaf-group-name="toData" id="spazi___model___formbean___DateOccupazForm___toData_year" name="spazi___model___formbean___DateOccupazForm___toData_year">
# <option value=""> </option><option value="2020">
# 2020</option>
# <option value="2021">
# 2021</option>
# <option value="2022">
# 2022</option>
# <option value="2023">
# 2023</option>
# <option value="2024">
# 2024</option>
# <option selected="" value="2025">
# 2025</option>
# <option value="2026">
# 2026</option>
# <option value="2027">
# 2027</option>
# <option value="2028">
# 2028</option>
# <option value="2029">
# 2029</option>
# <option value="2030">
# 2030</option>
# </select>
# <input name="jaf_spazi___model___formbean___DateOccupazForm___toData_date_format" type="hidden" value="dd/MM/yyyy"/><input disabled="disabled" id="spazi___model___formbean___DateOccupazForm___toData" name="spazi___model___formbean___DateOccupazForm___toData" type="hidden"/><script type="text/javascript">$(document).ready(function(){
# $("#spazi___model___formbean___DateOccupazForm___toData").datepicker(
#  $.extend({},
#  $.datepicker.regional['it'],
#  {
# yearRange: '2020:2030', minDate:new Date(2020, 0 , 1)
#   , maxDate:new Date(2030, 11, 31)
#   ,
# changeYear: true, constrainInput: true, duration: '' ,
# beforeShow: readLinked ,
# onSelect: updateLinked ,
# showOn: 'button' }
#  )
# );
# });
# </script> <label class="formValidationErrorMessage" for="spazi___model___formbean___DateOccupazForm___toData" style="display:none;"></label>
# </td>
# </tr>
# </table>
# <br/>
# <button class="jaf-btn-big" name="evn_occupazioni" type="submit" value="Visualizza occupazioni">Visualizza occupazioni
# </button>
# </form><script type="text/javascript">$().ready(function() {
# $("#occupaz_form").validate({
# rules : {
# spazi___model___formbean___DateOccupazForm___fromData_year : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='fromData']"
# },
# spazi___model___formbean___DateOccupazForm___fromData_month : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='fromData']"
# },
# spazi___model___formbean___DateOccupazForm___fromData_day : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='fromData']"
# },
# spazi___model___formbean___DateOccupazForm___toData_year : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='toData']"
# },
# spazi___model___formbean___DateOccupazForm___toData_day : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='toData']"
# },
# spazi___model___formbean___DateOccupazForm___toData_month : {
# required:true,
# skip_or_fill_all: "select[data-jaf-group-name='toData']"
# }
# },
# highlight: function( element, errorClass, validClass ) {
# $(element).addClass(errorClass).removeClass(validClass);
# var name = this.idOrName(element);
# $("label[for='"+name+"']:not('."+errorClass+"'):not('."+validClass+"')").addClass('formValidationErrorLabel');
# },
# unhighlight: function( element, errorClass, validClass ) {
# $(element).removeClass(errorClass).addClass(validClass);
# var name = this.idOrName(element);
# var cleanLabel = true;
# if(this.groups[element.name]){
# var groupName = name;
# for (var key in this.groups){
# var value = this.groups[key];
# if(value==groupName){
# if(! this.check("form#occupaz_form *[name='"+key+"']")){
# cleanLabel=false;
# break;
# }
# }
# }
# }
# if(cleanLabel){
# $("label[for='"+name+"']:not('."+errorClass+"'):not('."+validClass+"')").removeClass('formValidationErrorLabel');
# }else{
# this.toHide = this.toHide.not( this.errorsFor( element ) )}
# },
# groups : {
# spazi___model___formbean___DateOccupazForm___fromData : "spazi___model___formbean___DateOccupazForm___fromData_day spazi___model___formbean___DateOccupazForm___fromData_month spazi___model___formbean___DateOccupazForm___fromData_year",
# spazi___model___formbean___DateOccupazForm___toData : "spazi___model___formbean___DateOccupazForm___toData_day spazi___model___formbean___DateOccupazForm___toData_month spazi___model___formbean___DateOccupazForm___toData_year"
# },
# errorClass: "formValidationErrorMessage"
# }); $('.formValidationErrorMessage').attr('generated',true);});
# </script>
# </br></br></br></td>
# </tr></table>
# <table class="polifooter">
# <tfoot class="tfoot-tablePage">
# <tr>
# <td>
# <div class="jaf-text-align-left">
# 	   				 spazi v. 1.7.12 / 1.7.12
# 	   			</div>
# </td>
# <td>
# <div class="jaf-text-align-center">
# 					Area Servizi ICT
#     			</div>
# </td>
# <td>
# <div class="jaf-text-align-right" id="div-tfoot-tablePage-centerBar">
# </div>
# </td>
# </tr>
# </tfoot>
# </table>
# </div>
# </body>
# </html>

# %%
list(classroom_soup.find("em", string="Codice vano").parent.stripped_strings)[1]
# Out:
# 'MIB0212003026'

# %%
classroom_soup.find("h4", string="Allestimenti").find_next("tbody").find_all("td")
# Out:
# [<td class="Dati1">
#
#  		ATTREZZATURE
#      </td>,
#  <td class="Dati1">
#
#  		Radio microfono
#  	</td>,
#  <td class="Dati1">
#
#  		SI
#  	</td>,
#  <td class="Dati1">
#
#  		ATTREZZATURE
#      </td>,
#  <td class="Dati1">
#
#  		Oscurabile
#  	</td>,
#  <td class="Dati1">
#
#  		SI
#  	</td>,
#  <td class="Dati1">
#
#  		ATTREZZATURE
#      </td>,
#  <td class="Dati1">
#
#  		Cattedra cablata
#  	</td>,
#  <td class="Dati1">
#
#  		SI
#  	</td>,
#  <td class="Dati1">
#
#  		ATTREZZATURE
#      </td>,
#  <td class="Dati1">
#
#  		Video proiettore con PC
#  	</td>,
#  <td class="Dati1">
#
#  		SI
#  	</td>,
#  <td class="Dati1">
#
#  		ATTREZZATURE
#      </td>,
#  <td class="Dati1">
#
#  		Microfono
#  	</td>,
#  <td class="Dati1">
#
#  		SI
#  	</td>]

# %%
classroom_soup.find(
    "td", string=re.compile(r"\s+Postazioni dotate di presa elettrica\s+")
).find_next("td").string.strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 classroom_soup.find(
#       2     "td", string=re.compile(r"\s+Postazioni dotate di presa elettrica\s+")
# ----> 3 ).find_next("td").string.strip()
#
# AttributeError: 'NoneType' object has no attribute 'find_next'

# %% [markdown]
# ## Execute

# %%
classroom_data_list = []

for _, sede_series in tqdm(sede_df.iterrows(), total=sede_df.shape[0], desc="Sede"):
    logger.info("Processing sede {}", sede_series["codice_patrimonio"])
    sede_soup = occupancy_soup(sede_series["codice_patrimonio"], date(2025, 2, 3))
    occupancy_table = sede_soup.find("td", {"class": "MatriceOccupazioni"})
    if occupancy_table is None:
        logger.warning(
            "No classrooms found for sede {}", sede_series["codice_patrimonio"]
        )
        continue
    classroom_urls = [
        urljoin(URL, classroom.find("a")["href"])
        for classroom in occupancy_table.find_all("td", {"class": "dove"})
    ]
    for classroom_url in tqdm(classroom_urls, desc="Aula"):
        classroom_soup = BeautifulSoup(
            requests.get(classroom_url, timeout=5).text,
            "html.parser",
        )
        classroom_data = {}
        for key in ("Sigla", "Codice vano", "Indirizzo"):
            classroom_data[key] = list(
                classroom_soup.find("em", string=key).parent.stripped_strings
            )[1]
        electrical_socket_field = classroom_soup.find(
            "td", string=re.compile(r"\s+Postazioni dotate di presa elettrica\s+")
        )
        if electrical_socket_field is not None:
            logger.debug("Found electrical socket field")
            classroom_data["plugs"] = (
                electrical_socket_field.find_next("td").string.strip() == "SI"
            )
        classroom_data_list.append(classroom_data)
    logger.success("Processed sede {}", sede_series["codice_patrimonio"])
# Out:
# Sede:   0%|          | 0/11 [00:00<?, ?it/s]
# 2025-02-01 19:35:07.680 | INFO     | __main__:<module>:4 - Processing sede COE
# 2025-02-01 19:35:08.027 | WARNING  | __main__:<module>:8 - No classrooms found for sede COE
# 2025-02-01 19:35:08.028 | INFO     | __main__:<module>:4 - Processing sede CRG
# Aula:   0%|          | 0/17 [00:00<?, ?it/s]
# 2025-02-01 19:35:13.976 | SUCCESS  | __main__:<module>:35 - Processed sede CRG
# 2025-02-01 19:35:13.977 | INFO     | __main__:<module>:4 - Processing sede LCF
# Aula:   0%|          | 0/29 [00:00<?, ?it/s]
# 2025-02-01 19:35:14.792 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:15.098 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:15.404 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:15.712 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:16.026 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:16.766 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:17.024 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:17.453 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:17.725 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:18.070 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:18.383 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:18.783 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:19.093 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:19.401 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:19.709 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:20.013 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:20.319 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:20.627 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:21.429 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:21.755 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:22.069 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:22.678 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:23.293 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:23.605 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:23.606 | SUCCESS  | __main__:<module>:35 - Processed sede LCF
# 2025-02-01 19:35:23.607 | INFO     | __main__:<module>:4 - Processing sede MIB
# Aula:   0%|          | 0/110 [00:00<?, ?it/s]
# 2025-02-01 19:35:27.586 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:30.864 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:31.793 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:33.734 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:35.066 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:40.290 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:41.118 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:45.519 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:45.918 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:46.230 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:46.540 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:46.830 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:47.152 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:47.763 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:48.795 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:49.810 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:50.830 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:51.468 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:52.371 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:53.063 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:53.397 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:54.728 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:55.451 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:55.849 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:56.471 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:57.182 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:57.901 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:58.618 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:35:59.336 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:00.159 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:00.984 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:01.391 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:01.695 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:02.000 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:02.306 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:03.021 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:03.335 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:03.740 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:04.149 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:05.276 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:05.554 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:05.899 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:06.153 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:06.812 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:07.476 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:08.138 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:08.862 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:09.579 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:10.213 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:10.911 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:11.725 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:12.952 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:13.266 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:13.678 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:14.194 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:14.195 | SUCCESS  | __main__:<module>:35 - Processed sede MIB
# 2025-02-01 19:36:14.195 | INFO     | __main__:<module>:4 - Processing sede PCL
# Aula:   0%|          | 0/33 [00:00<?, ?it/s]
# 2025-02-01 19:36:25.033 | SUCCESS  | __main__:<module>:35 - Processed sede PCL
# 2025-02-01 19:36:25.034 | INFO     | __main__:<module>:4 - Processing sede MIA
# Aula:   0%|          | 0/154 [00:00<?, ?it/s]
# 2025-02-01 19:36:26.680 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:27.677 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:28.383 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:28.684 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:31.489 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:32.203 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:32.926 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:33.743 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:34.160 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:34.562 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:34.872 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:35.279 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:35.995 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:36.716 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:37.427 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:38.152 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:38.967 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:39.788 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:40.603 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:42.757 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:43.579 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:44.545 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:45.417 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:46.542 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:46.847 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:48.489 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:50.126 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:50.847 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:51.460 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:52.276 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:53.609 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:59.138 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:59.547 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:36:59.858 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:00.264 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:06.713 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:07.022 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:07.335 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:08.149 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:08.972 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:09.379 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:09.789 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:10.194 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:10.609 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:10.923 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:11.329 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:11.627 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:11.940 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:12.242 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:12.550 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:12.861 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:13.677 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:14.084 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:14.394 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:14.699 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:15.113 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:15.526 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:15.930 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:16.238 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:16.661 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:17.565 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:17.878 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:18.291 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:18.695 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:19.107 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:19.520 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:19.822 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:20.240 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:20.644 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:20.947 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:21.358 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:21.613 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:21.974 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:24.533 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:25.250 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:25.976 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:26.784 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:27.504 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:32.622 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:32.938 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:33.234 | DEBUG    | __main__:<module>:30 - Found electrical socket field
# 2025-02-01 19:37:33.235 | SUCCESS  | __main__:<module>:35 - Processed sede MIA
# 2025-02-01 19:37:33.236 | INFO     | __main__:<module>:4 - Processing sede MNI
# Aula:   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-02-01 19:37:36.360 | SUCCESS  | __main__:<module>:35 - Processed sede MNI
# 2025-02-01 19:37:36.361 | INFO     | __main__:<module>:4 - Processing sede MID
# 2025-02-01 19:37:36.544 | WARNING  | __main__:<module>:8 - No classrooms found for sede MID
# 2025-02-01 19:37:36.545 | INFO     | __main__:<module>:4 - Processing sede MIC
# 2025-02-01 19:37:36.691 | WARNING  | __main__:<module>:8 - No classrooms found for sede MIC
# 2025-02-01 19:37:36.693 | INFO     | __main__:<module>:4 - Processing sede MIF
# 2025-02-01 19:37:36.854 | WARNING  | __main__:<module>:8 - No classrooms found for sede MIF
# 2025-02-01 19:37:36.855 | INFO     | __main__:<module>:4 - Processing sede GEM
# 2025-02-01 19:37:37.220 | WARNING  | __main__:<module>:8 - No classrooms found for sede GEM

# %%
classroom_data_df = (
    pd.DataFrame(classroom_data_list)
    .rename(
        columns={
            "Sigla": "name",
            "Codice vano": "codice_patrimonio",
            "Indirizzo": "address",
        }
    )
    .drop_duplicates(subset="codice_patrimonio")
    .convert_dtypes()
)
classroom_data_df["plugs"] = classroom_data_df["plugs"].fillna(False)
classroom_data_df
# Out:
#                      name codice_patrimonio  \
# 0                A.1.1-CR     CRG0102001001
# 1                A.2.1-CR     CRG0102002001
# 2                A.2.2-CR     CRG0102002002
# 3    AULA STUDIO GIALLA 1    CRG0101000038b
# 4    AULA STUDIO GIALLA 2    CRG0101000038a
# ..                    ...               ...
# 348                 A 1.2     MNI0101001025
# 349                 A.1.3     MNI0101001001
# 350                 A.1.4     MNI0101001073
# 351                 A.1.5     MNI0101001061
# 352                 A.1.8     MNI0101001039
#
#                                         address  plugs
# 0          Via Sesto, 39 - 26100 - Cremona (CR)  False
# 1          Via Sesto, 39 - 26100 - Cremona (CR)  False
# 2          Via Sesto, 39 - 26100 - Cremona (CR)  False
# 3          Via Sesto, 41 - 26100 - Cremona (CR)  False
# 4          Via Sesto, 41 - 26100 - Cremona (CR)  False
# ..                                          ...    ...
# 348  Via Scarsellini, 15 - 46100 - Mantova (MN)  False
# 349  Via Scarsellini, 15 - 46100 - Mantova (MN)  False
# 350  Via Scarsellini, 15 - 46100 - Mantova (MN)  False
# 351  Via Scarsellini, 15 - 46100 - Mantova (MN)  False
# 352  Via Scarsellini, 15 - 46100 - Mantova (MN)  False
#
# [353 rows x 4 columns]

# %%
classroom_data_df.to_parquet(DataPath.RAW_CLASSROOMS)
